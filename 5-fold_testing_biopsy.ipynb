# %%
# Add yaml files  
from pathlib import Path

root = Path(
    "/home/zaman/Code/Breast_Cancer_Detection_and_Monitoring/Cancer.v1i.yolov8/5-fold"
)

for fold in range(1, 6):

    yaml_content = f"""
path: {root}/fold{fold}

train: train/images
val: val/images

nc: 4

names:
  0: breast cancer g1
  1: breast cancer g2
  2: breast cancer g3
  3: breast normalcell
"""

    with open(root / f"fold{fold}.yaml", "w") as f:
        f.write(yaml_content.strip())

print("Created fold1.yaml ... fold5.yaml")
# Out:
# Created fold1.yaml ... fold5.yaml

# %%
from ultralytics import YOLO
import pandas as pd
from pathlib import Path

ROOT = Path(
    "/home/zaman/Code/Breast_Cancer_Detection_and_Monitoring/Cancer.v1i.yolov8/5-fold"
)

results = []

for fold in range(1, 6):

    print(f"\n========== FOLD {fold} ==========\n")

    yaml_file = ROOT / f"fold{fold}.yaml"

    # -------------------------------------------------
    # CHANGE THIS TO YOUR MODEL
    # -------------------------------------------------

    model = YOLO("yolov8n.pt")

    model.train(
        data=str(yaml_file),
        epochs=100,
        imgsz=512,
        batch=4,
        name=f"fold{fold}",
        project="5fold_runs"
    )

    csv_path = (
        Path("5fold_runs")
        / f"fold{fold}"
        / "results.csv"
    )

    df = pd.read_csv(csv_path)

    best_idx = df["metrics/mAP50-95(B)"].idxmax()

    best = df.loc[best_idx]

    precision = best["metrics/precision(B)"]
    recall = best["metrics/recall(B)"]

    f1 = (
        2 * precision * recall
        / (precision + recall + 1e-9)
    )

    results.append({
        "Fold": fold,
        "Epoch": int(best["epoch"]),
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "mAP50": best["metrics/mAP50(B)"],
        "mAP50_95": best["metrics/mAP50-95(B)"]
    })

summary = pd.DataFrame(results)

summary.to_csv(
    "5fold_results.csv",
    index=False
)

print("\nSaved 5fold_results.csv")
# Out:
# ========== FOLD 1 ==========
#
# New https://pypi.org/project/ultralytics/8.4.61 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.165 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO
import pandas as pd
from pathlib import Path

# %%
FOLD = 5

# %%
ROOT = Path(
    "/home/zaman/Code/Breast_Cancer_Detection_and_Monitoring/Cancer.v1i.yolov8/5-fold"
)

yaml_file = ROOT / f"fold{FOLD}.yaml"

model = YOLO("yolov8n.pt")

model.train(
    data=str(yaml_file),
    epochs=100,
    imgsz=512,
    batch=4,
    project="5fold_runs",
    name=f"fold{FOLD}",
    exist_ok=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.61 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.165 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
import pandas as pd
from pathlib import Path

csv_path = Path(f"5fold_runs/fold{FOLD}/results.csv")

df = pd.read_csv(csv_path)

df.columns = df.columns.str.strip()

best_idx = df["metrics/mAP50-95(B)"].idxmax()

best = df.loc[best_idx]

precision = best["metrics/precision(B)"]
recall = best["metrics/recall(B)"]

f1 = 2 * precision * recall / (precision + recall + 1e-9)

result = pd.DataFrame([{
    "Fold": FOLD,
    "Best Epoch": int(best["epoch"]),
    "Precision": precision,
    "Recall": recall,
    "F1": f1,
    "mAP50": best["metrics/mAP50(B)"],
    "mAP50-95": best["metrics/mAP50-95(B)"]
}])

result
# Out:
#    Fold  Best Epoch  Precision   Recall        F1    mAP50  mAP50-95
# 0     5          99    0.95546  0.96169  0.958565  0.98631   0.97001

# %%
result.to_csv(
    f"fold_{FOLD}_summary.csv",
    index=False
)

print(f"Saved fold_{FOLD}_summary.csv")
# Out:
# Saved fold_5_summary.csv

# %%
#Run only after all the folds are completed
import pandas as pd

files = [
    "fold_1_summary.csv",
    "fold_2_summary.csv",
    "fold_3_summary.csv",
    "fold_4_summary.csv",
    "fold_5_summary.csv"
]

dfs = [pd.read_csv(f) for f in files]

all_folds = pd.concat(dfs, ignore_index=True)

all_folds
# Out:
#    Fold  Best Epoch  Precision   Recall        F1    mAP50  mAP50-95
# 0     1           2    0.41268  0.89640  0.565170  0.58038   0.50512
# 1     2          89    0.95522  0.95733  0.956274  0.97938   0.94198
# 2     3          90    0.91762  0.94671  0.931938  0.97530   0.94218
# 3     4          90    0.96484  0.96946  0.967144  0.98964   0.95569
# 4     5          99    0.95546  0.96169  0.958565  0.98631   0.97001

# %%
metrics = [
    "Precision",
    "Recall",
    "F1",
    "mAP50",
    "mAP50-95"
]

summary = []

for metric in metrics:

    summary.append({
        "Metric": metric,
        "Mean": all_folds[metric].mean(),
        "Std": all_folds[metric].std(),
        "Mean ± Std":
            f"{all_folds[metric].mean():.4f} ± "
            f"{all_folds[metric].std():.4f}"
    })

summary_df = pd.DataFrame(summary)

summary_df
# Out:
#       Metric      Mean       Std       Mean ± Std
# 0  Precision  0.841164  0.240215  0.8412 ± 0.2402
# 1     Recall  0.946318  0.029091  0.9463 ± 0.0291
# 2         F1  0.875818  0.174150  0.8758 ± 0.1741
# 3      mAP50  0.902202  0.179992  0.9022 ± 0.1800
# 4   mAP50-95  0.862996  0.200392  0.8630 ± 0.2004

# %%
paper_table = summary_df[["Metric", "Mean ± Std"]]

paper_table
# Out:
#       Metric       Mean ± Std
# 0  Precision  0.8412 ± 0.2402
# 1     Recall  0.9463 ± 0.0291
# 2         F1  0.8758 ± 0.1741
# 3      mAP50  0.9022 ± 0.1800
# 4   mAP50-95  0.8630 ± 0.2004

# %%
import matplotlib.pyplot as plt

metrics = [
    "Precision",
    "Recall",
    "F1",
    "mAP50",
    "mAP50-95"
]

ax = all_folds.set_index("Fold")[metrics].plot(
    kind="bar",
    figsize=(12,6)
)

plt.title("5-Fold Cross Validation Results")
plt.ylabel("Score")
plt.grid(axis="y", alpha=0.3)

plt.tight_layout()

plt.savefig(
    "5fold_comparison.png",
    dpi=300
)

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
